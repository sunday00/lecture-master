# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

arr = [ np.random.randint(1, 7) for _ in range(1, 1001) ]
arr
# Out:
# [1,
#  3,
#  6,
#  5,
#  3,
#  5,
#  6,
#  5,
#  6,
#  2,
#  1,
#  4,
#  6,
#  6,
#  5,
#  3,
#  4,
#  4,
#  6,
#  1,
#  1,
#  6,
#  3,
#  6,
#  3,
#  6,
#  3,
#  2,
#  3,
#  5,
#  2,
#  4,
#  3,
#  1,
#  4,
#  5,
#  6,
#  5,
#  5,
#  1,
#  5,
#  4,
#  4,
#  5,
#  6,
#  4,
#  6,
#  2,
#  2,
#  2,
#  2,
#  5,
#  1,
#  2,
#  2,
#  3,
#  1,
#  5,
#  1,
#  4,
#  1,
#  6,
#  3,
#  4,
#  1,
#  3,
#  5,
#  2,
#  5,
#  3,
#  5,
#  5,
#  5,
#  1,
#  1,
#  4,
#  3,
#  5,
#  3,
#  4,
#  4,
#  2,
#  5,
#  4,
#  2,
#  6,
#  6,
#  1,
#  5,
#  3,
#  4,
#  6,
#  3,
#  2,
#  6,
#  6,
#  3,
#  4,
#  5,
#  5,
#  6,
#  2,
#  3,
#  5,
#  2,
#  2,
#  1,
#  4,
#  6,
#  3,
#  5,
#  1,
#  3,
#  4,
#  4,
#  1,
#  3,
#  6,
#  4,
#  5,
#  2,
#  5,
#  1,
#  2,
#  5,
#  2,
#  5,
#  4,
#  5,
#  6,
#  3,
#  6,
#  1,
#  2,
#  2,
#  2,
#  6,
#  4,
#  2,
#  5,
#  4,
#  5,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  4,
#  4,
#  4,
#  4,
#  1,
#  2,
#  3,
#  4,
#  1,
#  5,
#  6,
#  1,
#  4,
#  1,
#  5,
#  3,
#  4,
#  5,
# ...

# %%
plt.grid(True)
plt.hist(arr)
plt.show()

# %%
arr = [ np.random.randint(1, 7) for _ in range(1, 1001) ]
plt.grid(True)
plt.hist(arr, bins=6, alpha=0.5)
plt.show()
