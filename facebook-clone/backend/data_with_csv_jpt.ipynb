# %%
import pandas as pd
import numpy as ny

data = pd.read_csv('./csv_Friend_data.csv')

# %%
data
# Out:
#      Unnamed: 0   id  current_user_id  user_id  room_id  created_at
# 0             0   26                4        1       15  2021-09-13
# 1             1   27                1        4       15  2021-09-13
# 2             2   28                1       96       16  2021-09-17
# 3             3   29                1       85       17  2021-09-17
# 4             4   30               85        1       17  2021-09-17
# ..          ...  ...              ...      ...      ...         ...
# 239         239  265                1      108      251  2021-09-18
# 240         240  266              163       95      252  2021-09-18
# 241         241  267              129      165      253  2021-09-18
# 242         242  268              137      156      254  2021-09-18
# 243         243  269               95      149      255  2021-09-18
#
# [244 rows x 6 columns]

# %%
data['created_at']
# Out:
# 0      2021-09-13
# 1      2021-09-13
# 2      2021-09-17
# 3      2021-09-17
# 4      2021-09-17
#           ...
# 239    2021-09-18
# 240    2021-09-18
# 241    2021-09-18
# 242    2021-09-18
# 243    2021-09-18
# Name: created_at, Length: 244, dtype: object

# %%
data['created_at'].value_counts()
# Out:
# 2021-09-18    237
# 2021-09-17      5
# 2021-09-13      2
# Name: created_at, dtype: int64

# %%
data['created_at'].value_counts().sort_index()
# Out:
# 2021-09-13      2
# 2021-09-17      5
# 2021-09-18    237
# Name: created_at, dtype: int64

# %%
data['created_at'].unique()
# Out:
# array(['2021-09-13', '2021-09-17', '2021-09-18'], dtype=object)

# %%
data = pd.read_csv('./csv_Profile_data.csv')

# %%
data
# Out:
#      Unnamed: 0   id  user_id         nick                         picture  \
# 0             0    1        1        joker  accounts/sunday00/vSuNgbYY.jpg
# 1             1    2        4       monday    accounts/monday/RIOVCCpv.jpg
# 2             2    3        5      tuesday   accounts/tuesday/VMPKrpNL.jpg
# 3             3    5       71     Mark2128                             NaN
# 4             4    6       72    Kelly4122                             NaN
# ..          ...  ...      ...          ...                             ...
# 118         118  120      186   Connor5081                             NaN
# 119         119  121      187     Sean5370                             NaN
# 120         120  122      188  Patrick1278                             NaN
# 121         121  123      189  Christy9930                             NaN
# 122         122  124      190   Ashley9365                             NaN
#
#                about  gender
# 0    symbol of chaos    male
# 1                NaN       N
# 2                NaN       N
# 3                NaN  female
# 4                NaN  female
# ..               ...     ...
# 118              NaN  female
# 119              NaN  female
# 120              NaN  female
# 121              NaN  female
# 122              NaN    male
#
# [123 rows x 7 columns]
